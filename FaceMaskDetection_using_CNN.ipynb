# %% [markdown]
# <a href="https://colab.research.google.com/github/daksh212004/ml-projects/blob/main/FaceMaskDetection_using_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.5)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.2.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.10)

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d omkargurav/face-mask-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/omkargurav/face-mask-dataset
# License(s): unknown
# face-mask-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
from zipfile import ZipFile
dataset = '/content/face-mask-dataset.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
# !ls
# Out:
# data  face-mask-dataset.zip  kaggle.json  sample_data

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split

# %%
with_mask=os.listdir('/content/data/with_mask')
without_mask=os.listdir('/content/data/without_mask')

# %%
print(with_mask)
# Out:
# ['with_mask_1359.jpg', 'with_mask_1720.jpg', 'with_mask_2776.jpg', 'with_mask_1605.jpg', 'with_mask_2265.jpg', 'with_mask_3681.jpg', 'with_mask_2695.jpg', 'with_mask_3708.jpg', 'with_mask_462.jpg', 'with_mask_18.jpg', 'with_mask_1758.jpg', 'with_mask_1220.jpg', 'with_mask_2986.jpg', 'with_mask_1536.jpg', 'with_mask_3535.jpg', 'with_mask_1003.jpg', 'with_mask_1306.jpg', 'with_mask_934.jpg', 'with_mask_1872.jpg', 'with_mask_2953.jpg', 'with_mask_1550.jpg', 'with_mask_2337.jpg', 'with_mask_2823.jpg', 'with_mask_300.jpg', 'with_mask_3228.jpg', 'with_mask_2700.jpg', 'with_mask_3158.jpg', 'with_mask_240.jpg', 'with_mask_2629.jpg', 'with_mask_962.jpg', 'with_mask_1826.jpg', 'with_mask_3323.jpg', 'with_mask_2631.jpg', 'with_mask_2503.jpg', 'with_mask_20.jpg', 'with_mask_3601.jpg', 'with_mask_2849.jpg', 'with_mask_3170.jpg', 'with_mask_909.jpg', 'with_mask_425.jpg', 'with_mask_1020.jpg', 'with_mask_1286.jpg', 'with_mask_2229.jpg', 'with_mask_548.jpg', 'with_mask_128.jpg', 'with_mask_2240.jpg', 'with_mask_1140.jpg', 'with_mask_2249.jpg', 'with_mask_479.jpg', 'with_mask_2568.jpg', 'with_mask_1738.jpg', 'with_mask_1264.jpg', 'with_mask_1578.jpg', 'with_mask_1763.jpg', 'with_mask_2319.jpg', 'with_mask_1519.jpg', 'with_mask_858.jpg', 'with_mask_818.jpg', 'with_mask_2948.jpg', 'with_mask_2601.jpg', 'with_mask_3079.jpg', 'with_mask_143.jpg', 'with_mask_1915.jpg', 'with_mask_1472.jpg', 'with_mask_665.jpg', 'with_mask_153.jpg', 'with_mask_456.jpg', 'with_mask_1169.jpg', 'with_mask_1171.jpg', 'with_mask_2116.jpg', 'with_mask_2798.jpg', 'with_mask_837.jpg', 'with_mask_976.jpg', 'with_mask_2042.jpg', 'with_mask_1328.jpg', 'with_mask_2420.jpg', 'with_mask_3371.jpg', 'with_mask_2460.jpg', 'with_mask_2392.jpg', 'with_mask_3028.jpg', 'with_mask_1444.jpg', 'with_mask_3134.jpg', 'with_mask_510.jpg', 'with_mask_333.jpg', 'with_mask_1974.jpg', 'with_mask_511.jpg', 'with_mask_2993.jpg', 'with_mask_3037.jpg', 'with_mask_1581.jpg', 'with_mask_405.jpg', 'with_mask_637.jpg', 'with_mask_831.jpg', 'with_mask_2876.jpg', 'with_mask_1202.jpg', 'with_mask_2658.jpg', 'with_mask_1700.jpg', 'with_mask_1440.jpg', 'with_mask_2846.jpg', 'with_mask_2959.jpg', 'with_mask_3657.jpg', 'with_mask_2558.jpg', 'with_mask_2617.jpg', 'with_mask_3675.jpg', 'with_mask_2413.jpg', 'with_mask_2327.jpg', 'with_mask_1045.jpg', 'with_mask_652.jpg', 'with_mask_2989.jpg', 'with_mask_572.jpg', 'with_mask_3128.jpg', 'with_mask_1392.jpg', 'with_mask_3653.jpg', 'with_mask_1236.jpg', 'with_mask_306.jpg', 'with_mask_791.jpg', 'with_mask_147.jpg', 'with_mask_1346.jpg', 'with_mask_2427.jpg', 'with_mask_3254.jpg', 'with_mask_950.jpg', 'with_mask_2407.jpg', 'with_mask_3215.jpg', 'with_mask_1476.jpg', 'with_mask_1010.jpg', 'with_mask_160.jpg', 'with_mask_1028.jpg', 'with_mask_2464.jpg', 'with_mask_1340.jpg', 'with_mask_2425.jpg', 'with_mask_2786.jpg', 'with_mask_433.jpg', 'with_mask_1512.jpg', 'with_mask_1492.jpg', 'with_mask_36.jpg', 'with_mask_2099.jpg', 'with_mask_1257.jpg', 'with_mask_1454.jpg', 'with_mask_3022.jpg', 'with_mask_966.jpg', 'with_mask_1745.jpg', 'with_mask_767.jpg', 'with_mask_631.jpg', 'with_mask_3621.jpg', 'with_mask_1017.jpg', 'with_mask_3203.jpg', 'with_mask_646.jpg', 'with_mask_679.jpg', 'with_mask_844.jpg', 'with_mask_1553.jpg', 'with_mask_1354.jpg', 'with_mask_2015.jpg', 'with_mask_1961.jpg', 'with_mask_188.jpg', 'with_mask_826.jpg', 'with_mask_1977.jpg', 'with_mask_1825.jpg', 'with_mask_196.jpg', 'with_mask_168.jpg', 'with_mask_3274.jpg', 'with_mask_597.jpg', 'with_mask_104.jpg', 'with_mask_1474.jpg', 'with_mask_2715.jpg', 'with_mask_2746.jpg', 'with_mask_1926.jpg', 'with_mask_793.jpg', 'with_mask_2154.jpg', 'with_mask_3617.jpg', 'with_mask_3099.jpg', 'with_mask_3707.jpg', 'with_mask_2063.jpg', 'with_mask_1777.jpg', 'with_mask_2903.jpg', 'with_mask_112.jpg', 'with_mask_835.jpg', 'with_mask_736.jpg', 'with_mask_3451.jpg', 'with_mask_183.jpg', 'with_mask_1387.jpg', 'with_mask_3595.jpg', 'with_mask_3470.jpg', 'with_mask_2701.jpg', 'with_mask_3695.jpg', 'with_mask_1780.jpg', 'with_ ...

# %%
print(without_mask)
# Out:
# ['without_mask_1998.jpg', 'without_mask_787.jpg', 'without_mask_2268.jpg', 'without_mask_3407.jpg', 'without_mask_2213.jpg', 'without_mask_2125.jpg', 'without_mask_198.jpg', 'without_mask_1121.jpg', 'without_mask_803.jpg', 'without_mask_3324.jpg', 'without_mask_3345.jpg', 'without_mask_1394.jpg', 'without_mask_74.jpg', 'without_mask_873.jpg', 'without_mask_1521.jpg', 'without_mask_1210.jpg', 'without_mask_1052.jpg', 'without_mask_2185.jpg', 'without_mask_3162.jpg', 'without_mask_2459.jpg', 'without_mask_2464.jpg', 'without_mask_2984.jpg', 'without_mask_1391.jpg', 'without_mask_2643.jpg', 'without_mask_3390.jpg', 'without_mask_3472.jpg', 'without_mask_820.jpg', 'without_mask_3063.jpg', 'without_mask_2951.jpg', 'without_mask_382.jpg', 'without_mask_454.jpg', 'without_mask_2419.jpg', 'without_mask_1234.jpg', 'without_mask_1799.jpg', 'without_mask_1489.jpg', 'without_mask_2211.jpg', 'without_mask_308.jpg', 'without_mask_260.jpg', 'without_mask_3761.jpg', 'without_mask_1749.jpg', 'without_mask_933.jpg', 'without_mask_1688.jpg', 'without_mask_697.jpg', 'without_mask_3459.jpg', 'without_mask_302.jpg', 'without_mask_2745.jpg', 'without_mask_1572.jpg', 'without_mask_2675.jpg', 'without_mask_733.jpg', 'without_mask_1356.jpg', 'without_mask_1973.jpg', 'without_mask_869.jpg', 'without_mask_1776.jpg', 'without_mask_3284.jpg', 'without_mask_1478.jpg', 'without_mask_2191.jpg', 'without_mask_1757.jpg', 'without_mask_2444.jpg', 'without_mask_3213.jpg', 'without_mask_1345.jpg', 'without_mask_3503.jpg', 'without_mask_3249.jpg', 'without_mask_3306.jpg', 'without_mask_1822.jpg', 'without_mask_711.jpg', 'without_mask_732.jpg', 'without_mask_1593.jpg', 'without_mask_3293.jpg', 'without_mask_1707.jpg', 'without_mask_3075.jpg', 'without_mask_1684.jpg', 'without_mask_1765.jpg', 'without_mask_1564.jpg', 'without_mask_504.jpg', 'without_mask_1954.jpg', 'without_mask_2846.jpg', 'without_mask_3818.jpg', 'without_mask_3259.jpg', 'without_mask_1486.jpg', 'without_mask_462.jpg', 'without_mask_1163.jpg', 'without_mask_2957.jpg', 'without_mask_1785.jpg', 'without_mask_668.jpg', 'without_mask_3366.jpg', 'without_mask_2017.jpg', 'without_mask_1215.jpg', 'without_mask_2264.jpg', 'without_mask_2435.jpg', 'without_mask_813.jpg', 'without_mask_2637.jpg', 'without_mask_2338.jpg', 'without_mask_3575.jpg', 'without_mask_3708.jpg', 'without_mask_2992.jpg', 'without_mask_1218.jpg', 'without_mask_423.jpg', 'without_mask_1434.jpg', 'without_mask_487.jpg', 'without_mask_3736.jpg', 'without_mask_3301.jpg', 'without_mask_3386.jpg', 'without_mask_2561.jpg', 'without_mask_3344.jpg', 'without_mask_1907.jpg', 'without_mask_3744.jpg', 'without_mask_1162.jpg', 'without_mask_2791.jpg', 'without_mask_2619.jpg', 'without_mask_2881.jpg', 'without_mask_1352.jpg', 'without_mask_3207.jpg', 'without_mask_2899.jpg', 'without_mask_2170.jpg', 'without_mask_2945.jpg', 'without_mask_1008.jpg', 'without_mask_315.jpg', 'without_mask_2761.jpg', 'without_mask_1641.jpg', 'without_mask_2590.jpg', 'without_mask_3440.jpg', 'without_mask_2528.jpg', 'without_mask_3550.jpg', 'without_mask_1554.jpg', 'without_mask_2106.jpg', 'without_mask_1114.jpg', 'without_mask_2563.jpg', 'without_mask_612.jpg', 'without_mask_2427.jpg', 'without_mask_776.jpg', 'without_mask_2130.jpg', 'without_mask_1302.jpg', 'without_mask_1818.jpg', 'without_mask_3754.jpg', 'without_mask_1774.jpg', 'without_mask_2889.jpg', 'without_mask_412.jpg', 'without_mask_3192.jpg', 'without_mask_3051.jpg', 'without_mask_2665.jpg', 'without_mask_1232.jpg', 'without_mask_2626.jpg', 'without_mask_2418.jpg', 'without_mask_2349.jpg', 'without_mask_510.jpg', 'without_mask_225.jpg', 'without_mask_3529.jpg', 'without_mask_193.jpg', 'without_mask_1036.jpg', 'without_mask_2894.jpg', 'without_mask_2686.jpg', 'without_mask_241.jpg', 'without_mask_3745.jpg', 'without_mask_1006.jpg', 'without_mask_3606.jpg', 'without_mask_1965.jpg', 'without_mask_1814.jpg', 'without_mask_1357.jpg', 'without_mask_2005.jpg', 'without_mask_514.jpg', 'without_mask_2380.jpg', 'withou ...

# %%
print("number of with_mask images ",len(with_mask))
print("number of without_mask images",len(without_mask))
# Out:
# number of with_mask images  3725
# number of without_mask images 3828

# %%
with_mask_labels=[1]*3725
without_mask_labels=[0]*3828
labels=with_mask_labels+without_mask_labels
print(len(labels))
# Out:
# 7553

# %%
img=mpimg.imread('/content/data/with_mask/with_mask_1720.jpg')
img1=plt.imshow(img)

# %%
img=mpimg.imread('/content/data/without_mask/without_mask_100.jpg')
img1=plt.imshow(img)

# %%
with_mask_path='/content/data/with_mask/'
data=[]
for img in with_mask:
  image=Image.open(with_mask_path+img)#image reading
  image=image.resize((128,128))
  image=image.convert('RGB')
  image=np.array(image)
  data.append(image)
# Out:
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
without_mask_path='/content/data/without_mask/'
for img in without_mask:
  image=Image.open(without_mask_path+img)#image reading
  image=image.resize((128,128))
  image=image.convert('RGB')
  image=np.array(image)
  data.append(image)

# %%
len(data)
# Out:
# 7553

# %%
type(data)
# Out:
# list

# %%
type(data[0])
# Out:
# numpy.ndarray

# %%
X=np.array(data)
Y=np.array(labels)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
X_train_scaled=X_train/255
X_test_scaled=X_test/255

# %%
print(X_train_scaled[0])
# Out:
# [[[0.96078431 0.89803922 0.8       ]
#   [0.96078431 0.89803922 0.8       ]
#   [0.96078431 0.89411765 0.8       ]
#   ...
#   [0.17647059 0.16078431 0.14901961]
#   [0.19607843 0.18039216 0.17647059]
#   [0.19215686 0.17647059 0.17254902]]
#
#  [[0.96078431 0.88627451 0.79215686]
#   [0.94901961 0.88235294 0.78431373]
#   [0.94509804 0.8745098  0.78039216]
#   ...
#   [0.14901961 0.12941176 0.11764706]
#   [0.16470588 0.14901961 0.13333333]
#   [0.16862745 0.15294118 0.14117647]]
#
#  [[0.94901961 0.87058824 0.76862745]
#   [0.9372549  0.86666667 0.76470588]
#   [0.9372549  0.85882353 0.76078431]
#   ...
#   [0.13333333 0.09803922 0.09411765]
#   [0.1372549  0.10196078 0.09019608]
#   [0.1372549  0.11372549 0.10196078]]
#
#  ...
#
#  [[0.51372549 0.42745098 0.25490196]
#   [0.51764706 0.43529412 0.2627451 ]
#   [0.51372549 0.43137255 0.2627451 ]
#   ...
#   [0.6        0.51372549 0.36862745]
#   [0.60784314 0.52156863 0.37647059]
#   [0.61568627 0.52941176 0.38431373]]
#
#  [[0.48627451 0.39607843 0.22352941]
#   [0.49803922 0.40784314 0.23529412]
#   [0.49411765 0.40392157 0.23529412]
#   ...
#   [0.6        0.51372549 0.36862745]
#   [0.6        0.51372549 0.36862745]
#   [0.60784314 0.52156863 0.37647059]]
#
#  [[0.49411765 0.4        0.22352941]
#   [0.49803922 0.40392157 0.22352941]
#   [0.49019608 0.39607843 0.22352941]
#   ...
#   [0.6        0.51372549 0.36862745]
#   [0.60392157 0.51764706 0.37254902]
#   [0.61176471 0.5254902  0.38039216]]]

# %% [markdown]
# Building a Convolutional Neural Network

# %%
import tensorflow as tf
from tensorflow import keras

# %%
num_of_classes=2
model=keras.Sequential()
model.add(keras.layers.Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=(128,128,3)))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(keras.layers.Conv2D(64,kernel_size=(3,3),activation='relu',input_shape=(128,128,3)))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(keras.layers.Flatten())

model.add(keras.layers.Dense(128,activation='relu'))
model.add(keras.layers.Dropout(0.5))

model.add(keras.layers.Dense(64,activation='relu'))
model.add(keras.layers.Dropout(0.5))

model.add(keras.layers.Dense(num_of_classes,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',loss=keras.losses.SparseCategoricalCrossentropy,metrics=['acc'])

# %%
history=model.fit(X_train_scaled,Y_train,validation_split=0.1,epochs=5)
# Out:
# Epoch 1/5
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - acc: 0.6629 - loss: 0.6361 - val_acc: 0.8975 - val_loss: 0.2461
# Epoch 2/5
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - acc: 0.8807 - loss: 0.3138 - val_acc: 0.9240 - val_loss: 0.2538
# Epoch 3/5
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.9078 - loss: 0.2464 - val_acc: 0.9339 - val_loss: 0.1912
# Epoch 4/5
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - acc: 0.9256 - loss: 0.1880 - val_acc: 0.9289 - val_loss: 0.1849
# Epoch 5/5
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.9396 - loss: 0.1690 - val_acc: 0.9289 - val_loss: 0.1858

# %%
loss,accuracy=model.evaluate(X_test_scaled,Y_test)
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - acc: 0.9125 - loss: 0.2238

# %%
h=history
plt.plot(h.history['loss'],label='trainloss')
plt.plot(h.history['val_loss'],label='valloss')
plt.legend()
plt.show()

# %%
h=history
plt.plot(h.history['acc'],label='trainacc')
plt.plot(h.history['val_acc'],label='valacc')
plt.legend()
plt.show()

# %%
from google.colab.patches import cv2_imshow

# %%
input_path='/content/106467352-1585602933667virus-medical-flu-mask-health-protection-woman-young-outdoor-sick-pollution-protective-danger-face_t20_o07dbe (1).jpg'

input_image = cv2.imread(input_path)
cv2_imshow(input_image)
input_image_resized = cv2.resize(input_image, (128,128))

input_image_scaled = input_image_resized/255

input_image_reshaped = np.reshape(input_image_scaled, [1,128,128,3])

input_prediction = model.predict(input_image_reshaped)
print(input_prediction)
input_pred_label = np.argmax(input_prediction)

if input_pred_label == 1:

  print('The person in the image is wearing a mask')

else:

  print('The person in the image is not wearing a mask')
# Out:
# <PIL.Image.Image image mode=RGB size=2200x1445>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# [[0.44593433 0.75397563]]
# The person in the image is wearing a mask
